# %% [markdown]
# # What is Pandas?

# %% [markdown]
# **Pandas** is a powerful and flexible open-source Python library used for data manipulation, analysis, and cleaning.
#
# It provides two primary data structures:
#
# **Series:** *1-dimensional* labeled array (like a column in a spreadsheet).
#
# **DataFrame:** *2-dimensional* labeled table (like an Excel sheet or SQL table).

# %% [markdown]
# ## Key Features of Pandas
#
# *   **Easy Data Loading:** Load data from CSV, Excel, SQL, JSON, etc.
# *   **Powerful Indexing:** Label-based and position-based indexing (.loc, .iloc).
# *   **Data Cleaning Tools:** Handle missing values, duplicates, outliers, etc.
# *   **Data Aggregation:** Summarize data with groupby, pivot_table, and agg().
# *   **Reshaping:** Use melt, pivot, stack, unstack to reshape data.
# *   **Merge and Join:** Combine multiple datasets like SQL joins (merge, concat).
# *   **Vectorized Operations:** Fast operations on entire columns (no need for loops).
# *   **Built-in Plotting:** Simple plots using .plot() with Matplotlib backend.

# %% [markdown]
# # What is the Iris Dataset?

# %% [markdown]
# The **Iris dataset** is a small, classic dataset in the field of machine learning and statistics. It contains measurements of flowers from three species of the iris plant:
#
# * Iris setosa
# * Iris versicolor
# * Iris virginica

# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Load the Dataset
# How to load a dataset from a CSV file into a DataFrame؟

# %%
data = pd.read_csv("/content/Iris.csv")
df = pd.DataFrame(data)

# %% [markdown]
# # Dataset Overview

# %% [markdown]
# **What does head() show us?**<br>
# It shows the first 5 rows of the DataFrame

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# How to show the last 5 rows of the DataFrame?

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# How do we get a random sample of rows?

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 64    65            5.6           2.9            3.6           1.3
# 134  135            6.1           2.6            5.6           1.4
# 92    93            5.8           2.6            4.0           1.2
# 34    35            4.9           3.1            1.5           0.1
# 108  109            6.7           2.5            5.8           1.8
# 102  103            7.1           3.0            5.9           2.1
# 63    64            6.1           2.9            4.7           1.4
# 104  105            6.5           3.0            5.8           2.2
# 66    67            5.6           3.0            4.5           1.5
# 70    71            5.9           3.2            4.8           1.8
#
#              Species
# 64   Iris-versicolor
# 134   Iris-virginica
# 92   Iris-versicolor
# 34       Iris-setosa
# 108   Iris-virginica
# 102   Iris-virginica
# 63   Iris-versicolor
# 104   Iris-virginica
# 66   Iris-versicolor
# 70   Iris-versicolor

# %% [markdown]
# How many rows and columns are in the dataset?

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# What are the column names?

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Data Types and Info
# How to explore column types and general information?

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# How to generate summary statistics of the dataset? <br>
# What are the mean, min, max and ... of numeric columns?

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# How to describe categorical data?

# %%
df.describe(include="object")
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %% [markdown]
# **What does value_counts() do?**<br>
# It returns the count of each unique value in a Series

# %% [markdown]
# How can we see how many times each species appears?

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Selecting Columns

# %% [markdown]
# How can we access a single column?

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# How can we select multiple columns?

# %%
df[['SepalLengthCm', 'SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# # Create a New Column
# How to create a new calculated column? <br>
# How can we create a new column based on existing ones?

# %%
df['SepalArea'] = df['SepalLengthCm'] * df['SepalWidthCm']

# %%
df['SepalArea']
# Out:
# 0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
#        ...
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Name: SepalArea, Length: 150, dtype: float64

# %% [markdown]
# # Missing Values
# How to check for missing values in a dataset?

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# SepalArea        0
# dtype: int64

# %% [markdown]
# # Filter Rows

# %% [markdown]
# How to filter rows based on conditions?

# %%
df[df['PetalWidthCm'] > 2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# 132  133            6.4           2.8            5.6           2.2
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 148  149            6.2           3.4            5.4           2.3
#
#             Species  SepalArea
# 100  Iris-virginica      20.79
# 102  Iris-virginica      21.30
# 104  Iris-virginica      19.50
# 105  Iris-virginica      22.80
# 109  Iris-virginica      25.92
# 112  Iris-virginica      20.40
# 114  Iris-virginica      16.24
# 115  Iris-virginica      20.48
# 117  Iris-virginica      29.26
# 118  Iris-virginica      20.02
# 120  Iris-virginica      22.08
# 124  Iris-virginica      22.11
# 128  Iris-virginica      17.92
# 132  Iris-virginica      17.92
# 135  Iris-virginica      23.10
# 136  Iris-virginica      21.42
# 139  Iris-virginica      21.39
# 140  Iris-virginica      20.77
# 141  Iris-virginica      21.39
# 143  Iris-virginica      21.76
# 144  Iris-virginica      22.11
# 145  Iris-virginica      20.10
# 148  Iris-virginica      21.08

# %%
df[df['Species'] == 'Iris-virginica']
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 116  117            6.5           3.0            5.5           1.8
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 119  120            6.0           2.2            5.0           1.5
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  SepalArea
# 100  Iris-virginica      20.79
# 101  Iris-virginica      15.66
# 102  Iris-virginica      21.30
# 103  Iris-virginica      18.27
# 104  Iris-virginica      19.50
# 105  Iris-virginica      22.80
# 106  Iris-virginica      12.25
# 107  Iris-virginica      21.17
# 108  Iris-virginica      16.75
# 109  Iris-virginica      25.92
# 110  Iris-virginica      20.80
# 111  Iris-virginica      17.28
# 112  Iris-virginica      20.40
# 113  Iris-virginica      14.25
# 114  Iris-virginica      16.24
# 115  Iris-virginica      20.48
# 116  Iris-virginica      19.50
# 117  Iris-virginica      29.26
# 118  Iris-virginica      20.02
# 119  Iris-virginica      13.20
# 120  Iris-virginica      22.08
# 121  Iris-virginica      15.68
# 122  Iris-virginica      21.56
# 123  Iris-virginica      17.01
# 124  Iris-virginica      22.11
# 125  Iris-virginica      23.04
# 126  Iris-virginica      17.36
# 127  Iris-virginica      18.30
# 128  Iris-virginica      17.92
# 129  Iris-virginica      21.60
# 130  Iris-virginica      20.72
# 131  Iris-virginica      30.02
# 132  Iris-virginica      17.92
# 133  Iris-virginica      17.64
# 134  Iris-virginica      15.86
# 135  Iris-virginica      23.10
# 136  Iris-virginica      21.42
# 137  Iris-virginica      19.84
# 138  Iris-virginica      18.00
# 139  Iris-virginica      21.39
# 140  Iris-virginica      20.77
# 141  Iris-virginica      21.39
# 142  Iris-virginica      15.66
# 143  Iris-virginica      21.76
# 144  Iris-virginica      22.11
# 145  Iris-virginica      20.10
# 146  Iris-virginica      15.75
# 147  Iris-virginica      19.50
# 148  Iris-virginica      21.08
# 149  Iris-virginica      17.70

# %% [markdown]
# # Grouping and Aggregation

# %% [markdown]
# How do we compute the mean for each group?

# %%
df.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm  SepalArea
# Species
# Iris-setosa             0.244    17.2088
# Iris-versicolor         1.326    16.5262
# Iris-virginica          2.026    19.6846

# %% [markdown]
# # Sorting Columns
# How do we sort rows by column values?

# %%
df.sort_values(by='SepalLengthCm', ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 42    43            4.4           3.2            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#             Species  SepalArea
# 131  Iris-virginica      30.02
# 122  Iris-virginica      21.56
# 118  Iris-virginica      20.02
# 117  Iris-virginica      29.26
# 135  Iris-virginica      23.10
# ..              ...        ...
# 41      Iris-setosa      10.35
# 42      Iris-setosa      14.08
# 8       Iris-setosa      12.76
# 38      Iris-setosa      13.20
# 13      Iris-setosa      12.90
#
# [150 rows x 7 columns]

# %% [markdown]
# What does this code do?

# %%
df.groupby('Species')['SepalWidthCm'].mean().sort_values(ascending=False)
# Out:
# Species
# Iris-setosa        3.418
# Iris-virginica     2.974
# Iris-versicolor    2.770
# Name: SepalWidthCm, dtype: float64

# %% [markdown]
# It groups the data by species, calculates the average sepal width, and sorts the result in descending order.

# %% [markdown]
# # Drop Columns
# How can we drop columns?

# %%
df.drop(columns=['SepalArea'], inplace=True)

# %% [markdown]
# # Renaming Columns
# How can we rename columns?

# %%
df.rename(columns={'SepalLengthCm': 'SepalLength'}, inplace=True)

# %%
df
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# How can we count unique values in each column?

# %%
df.nunique()
# Out:
# Id               150
# SepalLength       35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %% [markdown]
# How do we count unique species?

# %%
df['Species'].nunique()
# Out:
# 3

# %% [markdown]
#  # loc vs iloc

# %% [markdown]
# **What is the difference between loc and iloc?**<br>
# loc uses labels; iloc uses integer index positions

# %%
df.iloc[0]
# Out:
# Id                         1
# SepalLength              5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df.iloc[12]
# Out:
# Id                        13
# SepalLength              4.8
# SepalWidthCm             3.0
# PetalLengthCm            1.4
# PetalWidthCm             0.1
# Species          Iris-setosa
# Name: 12, dtype: object

# %%
df.iloc[0:2, 2:4]
# Out:
#    SepalWidthCm  PetalLengthCm
# 0           3.5            1.4
# 1           3.0            1.4

# %%
df.loc[0, 'PetalLengthCm']  # Specific value of a cell
# Out:
# np.float64(1.4)

# %%
df.loc[56, 'SepalWidthCm']
# Out:
# np.float64(3.3)

# %%
df.loc[56, 'Species']
# Out:
# 'Iris-versicolor'

# %% [markdown]
# # Pivot Table

# %% [markdown]
# **What is a pivot table?**<br>
# It aggregates values by groupings

# %% [markdown]
# How to summarize data using a pivot table?

# %%
df.pivot_table(values='SepalWidthCm', index='Species', aggfunc='mean')
# Out:
#                  SepalWidthCm
# Species
# Iris-setosa             3.418
# Iris-versicolor         2.770
# Iris-virginica          2.974

# %% [markdown]
# # Concatenate DataFrames
# How to concatenate rows and columns from multiple DataFrames?

# %%
df1 = df.iloc[:20]
df2 = df.iloc[70:80]

# %% [markdown]
# What does this code do?

# %%
pd.concat([df1, df2], axis=0) # axis=0 means row-wise concatenation (adds more rows)
# Out:
#     Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1          5.1           3.5            1.4           0.2
# 1    2          4.9           3.0            1.4           0.2
# 2    3          4.7           3.2            1.3           0.2
# 3    4          4.6           3.1            1.5           0.2
# 4    5          5.0           3.6            1.4           0.2
# 5    6          5.4           3.9            1.7           0.4
# 6    7          4.6           3.4            1.4           0.3
# 7    8          5.0           3.4            1.5           0.2
# 8    9          4.4           2.9            1.4           0.2
# 9   10          4.9           3.1            1.5           0.1
# 10  11          5.4           3.7            1.5           0.2
# 11  12          4.8           3.4            1.6           0.2
# 12  13          4.8           3.0            1.4           0.1
# 13  14          4.3           3.0            1.1           0.1
# 14  15          5.8           4.0            1.2           0.2
# 15  16          5.7           4.4            1.5           0.4
# 16  17          5.4           3.9            1.3           0.4
# 17  18          5.1           3.5            1.4           0.3
# 18  19          5.7           3.8            1.7           0.3
# 19  20          5.1           3.8            1.5           0.3
# 70  71          5.9           3.2            4.8           1.8
# 71  72          6.1           2.8            4.0           1.3
# 72  73          6.3           2.5            4.9           1.5
# 73  74          6.1           2.8            4.7           1.2
# 74  75          6.4           2.9            4.3           1.3
# 75  76          6.6           3.0            4.4           1.4
# 76  77          6.8           2.8            4.8           1.4
# 77  78          6.7           3.0            5.0           1.7
# 78  79          6.0           2.9            4.5           1.5
# 79  80          5.7           2.6            3.5           1.0
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor

# %% [markdown]
# **When should we use this?**<br>
# When we want to combine data as additional entries (rows)
#
#
# ---

# %% [markdown]
# What does this code do?

# %%
df1 = df['SepalLength']
df2 = df['PetalWidthCm']

pd.concat([df1, df2], axis=1) # axis=1 means column-wise concatenation (adds more columns)
# Out:
#      SepalLength  PetalWidthCm
# 0            5.1           0.2
# 1            4.9           0.2
# 2            4.7           0.2
# 3            4.6           0.2
# 4            5.0           0.2
# ..           ...           ...
# 145          6.7           2.3
# 146          6.3           1.9
# 147          6.5           2.0
# 148          6.2           2.3
# 149          5.9           1.8
#
# [150 rows x 2 columns]

# %% [markdown]
# **When should we use this?**<br>
# When we want to combine related columns for the same rows
#
#
# ---

# %% [markdown]
# # Merge with Another DataFrame
# How do we merge two DataFrames?

# %%
farsi_names = pd.DataFrame({
    'Species': ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
    'name_fa': ['ستوسا', 'ورسیکالر', 'ویرجینیکا']
})

# %%
farsi_names
# Out:
#            Species    name_fa
# 0      Iris-setosa      ستوسا
# 1  Iris-versicolor   ورسیکالر
# 2   Iris-virginica  ویرجینیکا

# %%
df.merge(farsi_names, on='Species')
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species    name_fa
# 0       Iris-setosa      ستوسا
# 1       Iris-setosa      ستوسا
# 2       Iris-setosa      ستوسا
# 3       Iris-setosa      ستوسا
# 4       Iris-setosa      ستوسا
# ..              ...        ...
# 145  Iris-virginica  ویرجینیکا
# 146  Iris-virginica  ویرجینیکا
# 147  Iris-virginica  ویرجینیکا
# 148  Iris-virginica  ویرجینیکا
# 149  Iris-virginica  ویرجینیکا
#
# [150 rows x 7 columns]

# %% [markdown]
# # Masking and Conditional Columns
# How do we label rows based on a condition?

# %%
df['LongSepal'] = df['SepalLength'].mask(df['SepalLength'] > 5, 'long')

# %%
df['LongSepal'].value_counts()
# Out:
# LongSepal
# long    118
# 5.0      10
# 4.9       6
# 4.8       5
# 4.6       4
# 4.4       3
# 4.7       2
# 4.3       1
# 4.5       1
# Name: count, dtype: int64

# %%
df['LongSepal']
# Out:
# 0      long
# 1       4.9
# 2       4.7
# 3       4.6
# 4       5.0
#        ...
# 145    long
# 146    long
# 147    long
# 148    long
# 149    long
# Name: LongSepal, Length: 150, dtype: object

# %% [markdown]
# # Apply Functions to Columns

# %% [markdown]
# **What is the difference between apply and map?**<br>
# apply works on Series/DataFrames, map only on Series

# %% [markdown]
# **How does apply() work on columns?**<br>
# It applies a function to each row or column.

# %% [markdown]
# How to apply a function to every value in a column?

# %%
df[['SepalLength', 'SepalWidthCm']].apply(lambda x: x.mean(), axis=0)
# Out:
# SepalLength     5.843333
# SepalWidthCm    3.054000
# dtype: float64

# %%
df['species_length'] = df['Species'].map(len)

# %%
df
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species LongSepal  species_length
# 0       Iris-setosa      long              11
# 1       Iris-setosa       4.9              11
# 2       Iris-setosa       4.7              11
# 3       Iris-setosa       4.6              11
# 4       Iris-setosa       5.0              11
# ..              ...       ...             ...
# 145  Iris-virginica      long              14
# 146  Iris-virginica      long              14
# 147  Iris-virginica      long              14
# 148  Iris-virginica      long              14
# 149  Iris-virginica      long              14
#
# [150 rows x 8 columns]

# %%
df['sepal_label'] = df['SepalLength'].apply(lambda x: 'short' if x < 5 else 'long')

# %%
df
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species LongSepal  species_length sepal_label
# 0       Iris-setosa      long              11        long
# 1       Iris-setosa       4.9              11       short
# 2       Iris-setosa       4.7              11       short
# 3       Iris-setosa       4.6              11       short
# 4       Iris-setosa       5.0              11        long
# ..              ...       ...             ...         ...
# 145  Iris-virginica      long              14        long
# 146  Iris-virginica      long              14        long
# 147  Iris-virginica      long              14        long
# 148  Iris-virginica      long              14        long
# 149  Iris-virginica      long              14        long
#
# [150 rows x 9 columns]

# %% [markdown]
# # Save the Modified Dataset
# How to export a DataFrame to a CSV file?

# %%
df.to_csv("iris_modified.csv", index=False)
